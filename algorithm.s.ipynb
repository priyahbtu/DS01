# %%
print("hello")
# Out:
# hello

# %%
arr=[1,2,3,4,5]
arr[1]=10
print(arr)
# Out:
# [1, 10, 3, 4, 5]

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def append(self,data):
        cur_node=self.head
        while cur_node:
            print(cur_node.data,end="->")
            cur_node=cur_node.next
        print(None)

list=LinkedList()
list.append(2)
list.append(3)
list.print_list()
None
# Out:
# None
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 20
#      18 list.append(2)
#      19 list.append(3)
# ---> 20 list.print_list()
#      21 None
#
# AttributeError: 'LinkedList' object has no attribute 'print_list'

# %%
stack = []

# Push ele
stack.append(1)
stack.append(2)
stack.append(3)

# Pop elem
print(stack.pop()) 
print(stack.pop())
# Out:
# 3
# 2

# %%
#Using Collections.deque
from collections import deque

queue = deque()

# Enqueue ele
queue.append(1)
queue.append(2)
queue.append(3)

# Dequeue ele
print(queue.popleft()) 
print(queue.popleft())
# Out:
# 1
# 2

# %%
#Basic Operations
class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def insert(root, key):
    if root is None:
        return TreeNode(key)
    if key < root.val:
        root.left = insert(root.left, key)
    else:
        root.right = insert(root.right, key)
    return root

def inorder(root):
    if root:
        inorder(root.left)
        print(root.val, end=" ")
        inorder(root.right)

# Usage
root = None
keys = [20, 8, 22, 4, 12, 10, 14]
for key in keys:
    root = insert(root, key)
inorder(root)
# Out:
# 4 8 10 12 14 20 22

# %%
#Sorting algorithm
##(1) Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

arr = [64, 34, 25, 12, 22, 11, 90]
bubble_sort(arr)
print(arr)
# Out:
# [11, 12, 22, 25, 34, 64, 90]
